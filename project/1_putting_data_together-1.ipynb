# %%
# import pandas and numpy
import pandas as pd
import numpy as np

# %%
# import 'School Quality Results' worksheet, 2014-15; header starts on 2nd line; sheet #1
sqr150 = pd.read_excel('2014_2015_HS_SQR_Results_2016_01_07.xlsx', sheetname=0, header=1)
sqr150.head()
# Out:
#       DBN                                        School Name  School Type  \
# 0  01M292      Henry Street School for International Studies  High School
# 1  01M448                University Neighborhood High School  High School
# 2  01M450                         East Side Community School  High School
# 3  01M509                            Marta Valle High School  High School
# 4  01M539  New Explorations into Science, Technology and ...  High School
#
#    Enrollment Rigorous Instruction Rating Collaborative Teachers Rating  \
# 0         255          Not Meeting Target            Approaching Target
# 1         304              Meeting Target                Meeting Target
# 2         666            Exceeding Target              Exceeding Target
# 3         363          Approaching Target            Approaching Target
# 4        1735            Exceeding Target            Approaching Target
#
#   Supportive Environment Rating Effective School Leadership Rating  \
# ...

# %%
# follow same steps with SQR worksheet; 2013-2014; header starts on 2nd line; sheet #1
sqr140 = pd.read_excel('2013_2014_HS_SQR_Results_2015_03_02.xlsx', sheetname=0, header=1)
sqr140.head()
# Out:
#       DBN                                        School Name  School Type  \
# 0  01M292      Henry Street School for International Studies  High School
# 1  01M448                University Neighborhood High School  High School
# 2  01M450                         East Side Community School  High School
# 3  01M509                            Marta Valle High School  High School
# 4  01M539  New Explorations into Science, Technology and ...  High School
#
#   Most Recent Quality Review Quality Review Rating     Progress Rating  \
# 0            April 8-9, 2014            Proficient  Approaching Target
# 1     February 13 - 14, 2013            Proficient    Exceeding Target
# 2                        NaN                   NaN      Meeting Target
# 3              May 5-6, 2014            Developing  Approaching Target
# 4        May 19-20, 23, 2011            Proficient    Exceeding Target
#
#    Achievement Rating  Environment Rating College and Career Readiness Rating  \
# ...

# %%
sqr150.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 0 to 490
# Data columns (total 40 columns):
# DBN                                                                                       491 non-null object
# School Name                                                                               491 non-null object
# School Type                                                                               491 non-null object
# Enrollment                                                                                491 non-null int64
# Rigorous Instruction Rating                                                               431 non-null object
# Collaborative Teachers Rating                                                             431 non-null object
# Supportive Environment Rating                                                             427 non-null object
# ...

# %%
sqr140.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 484 entries, 0 to 483
# Data columns (total 36 columns):
# DBN                                                                                      484 non-null object
# School Name                                                                              484 non-null object
# School Type                                                                              484 non-null object
# Most Recent Quality Review                                                               325 non-null object
# Quality Review Rating                                                                    325 non-null object
# Progress Rating                                                                          390 non-null object
# Achievement Rating                                                                       390 non-null object
# Environment Rating                                                                       390 non-null object
# ...

# %%
# get rid of unimportant/non-crossover columns and keep crucial ones; note:  DBN is a unique identifier for each school
base15 = pd.DataFrame(data=[sqr150['DBN'], sqr150['Enrollment'],
                           sqr150['Supportive Environment - Percent Positive'], sqr150['Average Grade 8 English Proficiency'],
                           sqr150['Average Grade 8 Math Proficiency'], sqr150['Percent English Language Learners'],
                           sqr150['Percent Students with Disabilities'], sqr150['Percent Self-Contained'],
                           sqr150['Percent Asian'], sqr150['Percent Black'],
                           sqr150['Percent Hispanic'], sqr150['Percent White'],
                           sqr150['Years of principal experience at this school'], sqr150['Student Attendance Rate'],
                           sqr150['Teacher Attendance Rate'], sqr150['School Name']])
base15.head()
# Out:
#                                               0       1       2       3    \
# DBN                                        01M292  01M448  01M450  01M509
# Enrollment                                    255     304     666     363
# Supportive Environment - Percent Positive    0.77    0.87    0.92    0.81
# Average Grade 8 English Proficiency          2.18    2.27    2.66    2.28
# Average Grade 8 Math Proficiency             2.06    2.37    2.63    2.09
#
#                                               4       5       6       7    \
# DBN                                        01M539  01M696  02M047  02M135
# Enrollment                                   1735     545     169     193
# Supportive Environment - Percent Positive    0.85    0.91    0.85    0.88
# Average Grade 8 English Proficiency           3.5    3.71     2.4    2.34
# Average Grade 8 Math Proficiency             3.53    3.65    2.24    2.22
#
# ...

# %%
# get rid of unimportant/non-crossover columns and keep crucial ones; note:  DBN is a unique identifier for each school
base14 = pd.DataFrame(data=[sqr140['DBN'], sqr140['Enrollment'], sqr140['Average Grade 8 English Proficiency'],
                           sqr140['Average Grade 8 Math Proficiency'], sqr140['% ELL'],
                           sqr140['% Students with Disabilities'], sqr140['% Self-Contained'],
                           sqr140['Percent Asian'], sqr140['Percent Black'],
                           sqr140['Percent Hispanic'], sqr140['Percent White'],
                           sqr140['Years of Principal Experience at This School'],
                           sqr140['Teacher Attendance'], sqr140['School Name']])
base14.head()
# Out:
#                                           0         1         2         3    \
# DBN                                    01M292    01M448    01M450    01M509
# Enrollment                                258       299       388       401
# Average Grade 8 English Proficiency     2.174   2.22708   2.66011   2.34355
# Average Grade 8 Math Proficiency      2.07419   2.25908   2.58496   2.15377
# % ELL                                0.217054  0.280936  0.028351  0.082294
#
#                                           4         5         6         7    \
# DBN                                    01M539    01M696    02M047    02M135
# Enrollment                                610       560       184       116
# Average Grade 8 English Proficiency   3.48103   3.70464   2.29976   2.39354
# Average Grade 8 Math Proficiency      3.48698   3.64018   2.16857   2.22522
# % ELL                                0.003279  0.003571  0.070652  0.068966
#
# ...

# %%
base15 = base15.transpose()
base15.head()
# Out:
#       DBN Enrollment Supportive Environment - Percent Positive  \
# 0  01M292        255                                      0.77
# 1  01M448        304                                      0.87
# 2  01M450        666                                      0.92
# 3  01M509        363                                      0.81
# 4  01M539       1735                                      0.85
#
#   Average Grade 8 English Proficiency Average Grade 8 Math Proficiency  \
# 0                                2.18                             2.06
# 1                                2.27                             2.37
# 2                                2.66                             2.63
# 3                                2.28                             2.09
# 4                                 3.5                             3.53
#
#   Percent English Language Learners Percent Students with Disabilities  \
# 0                             0.127                              0.298
# ...

# %%
base14 = base14.transpose()

# %%
# import 'School Quality Results' worksheet, 2014-15; header starts on 2nd line; sheet #5
sqr154 = pd.read_excel('2014_2015_HS_SQR_Results_2016_01_07.xlsx', sheetname=4, header=1)
sqr154.head()
# Out:
#       DBN                                        School Name  \
# 0  01M292      Henry Street School for International Studies
# 1  01M448                University Neighborhood High School
# 2  01M450                         East Side Community School
# 3  01M509                            Marta Valle High School
# 4  01M539  New Explorations into Science, Technology and ...
#
#    Average Score Regents Algebra  Percentage Passing Regents Algebra  \
# 0                             64                               0.524
# 1                             64                               0.550
# 2                            NaN                                 NaN
# 3                             61                               0.407
# 4                             80                               0.915
#
#    Percentage at college ready threshold Regents Algebra  \
# 0                                              0.063
# 1                                              0.042
# ...

# %%
# import 'School Quality Results' worksheet, 2013-14; header starts on 2nd line; sheet #7
sqr146 = pd.read_excel('2013_2014_HS_SQR_Results_2015_03_02.xlsx', sheetname=6, header=1)
sqr146.head()
# Out:
#       DBN                                             School  \
# 0  01M292      Henry Street School for International Studies
# 1  01M448                University Neighborhood High School
# 2  01M450                         East Side Community School
# 3  01M509                            Marta Valle High School
# 4  01M539  New Explorations into Science, Technology and ...
#
#    Average Score Regents Integrated Algebra  % Passing  \
# 0                                        58      0.390
# 1                                        68      0.614
# 2                                       NaN        NaN
# 3                                        61      0.463
# 4                                        86      0.957
#
#    % at college ready threshold  Average Score Regents Geometry  % Passing.1  \
# 0                         0.000                             NaN          NaN
# 1                         0.216                              66        0.571
# ...

# %%
list(sqr154)
# Out:
# [u'DBN',
#  u'School Name',
#  u'Average Score Regents Algebra',
#  u'Percentage Passing Regents Algebra',
#  u'Percentage at college ready threshold Regents Algebra',
#  u'Average Score Regents Geometry',
#  u'Percentage Passing Regents Geometry',
#  u'Percentage at college ready threshold Regents Geometry',
#  u'Average Score Regents Algebra 2/Trig',
#  u'Percentage Passing Regents Algebra 2/Trig',
#  u'Percentage at college ready threshold Regents Algebra 2/Trig',
#  u'Average Score Regents English',
#  u'Percentage Passing Regents English',
#  u'Percentage at college ready threshold Regents English',
#  u'Average Score Regents US History',
#  u'Percentage Passing Regents US History',
#  u'Average Score Regents Global History',
#  u'Percentage Passing Regents Global History',
#  u'Average Score Regents Chemistry',
#  u'Percentage Passing Regents Chemistry',
#  u'Average Score Regents Physics',
#  u'Percentage Passing Regents Physics',
#  u'Average Score Regents Earth Science',
# ...

# %%
list(sqr146)
# Out:
# [u'DBN',
#  u'School',
#  u'Average Score Regents Integrated Algebra',
#  u'% Passing',
#  u'% at college ready threshold',
#  u'Average Score Regents Geometry',
#  u'% Passing.1',
#  u'% at college ready threshold.1',
#  u'Average Score Regents Algebra 2/Trig',
#  u'% Passing.2',
#  u'% at college ready threshold.2',
#  u'Average Score Regents English',
#  u'% Passing.3',
#  u'% at college ready threshold.3',
#  u'Average Score Regents US History',
#  u'% Passing.4',
#  u'Average Score Regents Global History',
#  u'% Passing.5',
#  u'Average Score Regents Chemistry',
#  u'% Passing.6',
#  u'Average Score Regents Physics',
#  u'% Passing.7',
#  u'Average Score Regents Earth Science',
#  u'% Passing.8',
#  u'Average Score Regents Living Environment',
#  u'% Passing.9',
#  u'Average Score Regents Languages Other Than English',
#  u'% Passing.10',
#  u'Average Score SAT Math',
#  u'% of 4-year Cohort Taking SAT Math',
#  u'% College Ready SAT Math',
# ...

# %%
# get rid of unimportant/non-crossover columns and keep crucial ones; note:  DBN is a unique identifier for each school
sqr154 = pd.DataFrame(data=[sqr154['DBN'], sqr154['Average Score Regents Algebra'],
                           sqr154['Average Score Regents Geometry'], sqr154['Average Score Regents Algebra 2/Trig'],
            sqr154['Average Score Regents English'],
                           sqr154['Average Score Regents US History'], sqr154['Average Score Regents Global History'],
                           sqr154['Average Score Regents Chemistry'], sqr154['Average Score Regents Physics'],
                           sqr154['Average Score Regents Earth Science'], sqr154['Average Score Regents Living Environment'],
                           sqr154['Average Score Regents Languages Other Than English'], sqr154['Average Score SAT Math'],
                           sqr154['Percentage of 4-year Cohort Taking SAT Math'], sqr154['Average Score SAT Critical Reading'],
                           sqr154['Average Score SAT Writing'], sqr154['Percentage of 4-year Cohort Taking ACT Math'],
                           sqr154['Post-secondary Enrollment Rate (6 months)'], sqr154['CUNY 2-Year (6 months)'],
                           sqr154['CUNY 4-Year (6 months)'], sqr154['NYS Public (6 months)'],
                           sqr154['NYS Private (6 months)'], sqr154['Out of State (6 months)'],
                           sqr154['Public Service (6 months)'], sqr154['Vocational Program (6 months)'],
                           sqr154['CRI (Percentage of 4 year Cohort)'], sqr154['College and Career Preparatory Course Index'],
                           sqr154['Percentage Earning a Diploma with a CTE Endorsement'], sqr154['Percentage Passing an Industry-Recognized Technical Assessment'],
                           sqr154['Percentage of 4-year Cohort Taking SAT Math'], sqr154['Average Score SAT Critical Reading'],
                           sqr154['Percentage Earning a Diploma with an Arts Endorsement'], sqr154['Percentage Scoring 3+ on any AP Exam']])
sqr154.head()
# Out:
#                                          0       1       2       3       4    \
# DBN                                   01M292  01M448  01M450  01M509  01M539
# Average Score Regents Algebra             64      64     NaN      61      80
# Average Score Regents Geometry            58      68     NaN      66      83
# Average Score Regents Algebra 2/Trig     NaN      62     NaN      74      80
# Average Score Regents English             66      69      75      69      91
#
#                                          5       6       7       8       9    \
# DBN                                   01M696  02M047  02M135  02M139  02M280
# Average Score Regents Algebra             73      60      62      60      66
# Average Score Regents Geometry           NaN      57      72      52      73
# Average Score Regents Algebra 2/Trig     NaN     NaN     NaN     NaN     NaN
# Average Score Regents English             92      67      85     NaN     NaN
#
# ...

# %%
# get rid of unimportant/non-crossover columns and keep crucial ones; note:  DBN is a unique identifier for each school
sqr146 = pd.DataFrame(data=[sqr146['DBN'], sqr146['Average Score Regents Integrated Algebra'],
                           sqr146['Average Score Regents Geometry'], sqr146['Average Score Regents Algebra 2/Trig'], sqr146['Average Score Regents English'],
                           sqr146['Average Score Regents US History'], sqr146['Average Score Regents Global History'],
                           sqr146['Average Score Regents Chemistry'], sqr146['Average Score Regents Physics'],
                           sqr146['Average Score Regents Earth Science'], sqr146['Average Score Regents Living Environment'],
                           sqr146['Average Score Regents Languages Other Than English'], sqr146['Average Score SAT Math'],
                           sqr146['% of 4-year Cohort Taking SAT Math'], sqr146['Average Score SAT Critical Reading'],
                           sqr146['Average Score SAT Writing'], sqr146['% of 4-year Cohort Taking ACT Math'],
                           sqr146['Post-secondary Enrollment Rate (6 months)'], sqr146['CUNY 2-Year (6 months)'],
                           sqr146['CUNY 4-Year (6 months)'], sqr146['NYS Public (6 months)'],
                           sqr146['NYS Private (6 months)'], sqr146['Out of State (6 months)'],
                           sqr146['Public Service (6 months)'], sqr146['Vocational Program (6 months)'],
                           sqr146['CRI (% of 4 year Cohort)'], sqr146['College and Career Preparatory Course Index'],
                           sqr146['% earning a diploma with a CTE Endorsement'], sqr146['% passing an industry-recognized technical assessment'],
sqr146['% earning a diploma with an Arts endorsement'], sqr146['% scoring 3+ on any AP exam']])
sqr146.head()
# Out:
#                                              0       1       2       3    \
# DBN                                       01M292  01M448  01M450  01M509
# Average Score Regents Integrated Algebra      58      68     NaN      61
# Average Score Regents Geometry               NaN      66     NaN      66
# Average Score Regents Algebra 2/Trig          41      56     NaN      52
# Average Score Regents English                 63      65      73      68
#
#                                              4       5       6       7    \
# DBN                                       01M539  01M696  02M047  02M135
# Average Score Regents Integrated Algebra      86      76      61      68
# Average Score Regents Geometry                85     NaN      57     NaN
# Average Score Regents Algebra 2/Trig          81     NaN      46     NaN
# Average Score Regents English                 87      86      68     NaN
#
#                                              8       9       10      11   \
# ...

# %%
sqr146 = sqr146.transpose()

# %%
sqr154 = sqr154.transpose()

# %%
# merge two dataframes that contain sqr sheets 0 and 4 - 2015
base15 = pd.merge(base15, sqr154, how='left', on=['DBN'])
base15.head()
# Out:
#       DBN Enrollment Supportive Environment - Percent Positive  \
# 0  01M292        255                                      0.77
# 1  01M448        304                                      0.87
# 2  01M450        666                                      0.92
# 3  01M509        363                                      0.81
# 4  01M539       1735                                      0.85
#
#   Average Grade 8 English Proficiency Average Grade 8 Math Proficiency  \
# 0                                2.18                             2.06
# 1                                2.27                             2.37
# 2                                2.66                             2.63
# 3                                2.28                             2.09
# 4                                 3.5                             3.53
#
#   Percent English Language Learners Percent Students with Disabilities  \
# 0                             0.127                              0.298
# ...

# %%
base15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 0 to 490
# Data columns (total 48 columns):
# DBN                                                               491 non-null object
# Enrollment                                                        491 non-null object
# Supportive Environment - Percent Positive                         491 non-null object
# Average Grade 8 English Proficiency                               491 non-null object
# Average Grade 8 Math Proficiency                                  491 non-null object
# Percent English Language Learners                                 491 non-null object
# Percent Students with Disabilities                                491 non-null object
# Percent Self-Contained                                            491 non-null object
# Percent Asian                                                     491 non-null object
# Percent Black                                                     491 non-null object
# ...

# %%
# merge two dataframes that contain sqr sheets 0 and 6 - 2014
base14 = pd.merge(base14, sqr146, how='left', on=['DBN'])
base14.head()
# Out:
#       DBN Enrollment Average Grade 8 English Proficiency  \
# 0  01M292        258                               2.174
# 1  01M448        299                             2.22708
# 2  01M450        388                             2.66011
# 3  01M509        401                             2.34355
# 4  01M539        610                             3.48103
#
#   Average Grade 8 Math Proficiency     % ELL % Students with Disabilities  \
# 0                          2.07419  0.217054                     0.317829
# 1                          2.25908  0.280936                      0.29097
# 2                          2.58496  0.028351                     0.270619
# 3                          2.15377  0.082294                     0.276808
# 4                          3.48698  0.003279                     0.068852
#
#   % Self-Contained Percent Asian Percent Black Percent Hispanic Percent White  \
# 0         0.124031      0.143411      0.248062         0.554264      0.027132
# ...

# %%
base14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 484 entries, 0 to 483
# Data columns (total 44 columns):
# DBN                                                      484 non-null object
# Enrollment                                               478 non-null object
# Average Grade 8 English Proficiency                      478 non-null object
# Average Grade 8 Math Proficiency                         478 non-null object
# % ELL                                                    478 non-null object
# % Students with Disabilities                             478 non-null object
# % Self-Contained                                         478 non-null object
# Percent Asian                                            478 non-null object
# Percent Black                                            478 non-null object
# Percent Hispanic                                         478 non-null object
# Percent White                                            478 non-null object
# ...

# %%
# import 'School Quality Results' worksheet, 2013-14; header starts on 2nd line; sheet #4
sqr143 = pd.read_excel('2013_2014_HS_SQR_Results_2015_03_02.xlsx', sheetname=3, header=1)
sqr143.head()
# Out:
#       DBN                                        School Name  \
# 0  01M292      Henry Street School for International Studies
# 1  01M448                University Neighborhood High School
# 2  01M450                         East Side Community School
# 3  01M509                            Marta Valle High School
# 4  01M539  New Explorations into Science, Technology and ...
#
#    Environment Score  Environment Rating  Attendance Rate  \
# 0               22.8  Approaching Target            0.707
# 1               78.8    Exceeding Target            0.860
# 2               75.8    Exceeding Target            0.915
# 3                8.2  Not Meeting Target            0.775
# 4               28.6  Approaching Target            0.949
#
#    Peer Percent of Range  Peer 0% of Range  Peer Average  Peer 100% of Range  \
# 0                  0.000             0.724         0.812               0.900
# 1                  0.764             0.747         0.821               0.895
# ...

# %%
list(sqr143)
# Out:
# [u'DBN',
#  u'School Name',
#  u'Environment Score',
#  u'Environment Rating',
#  u'Attendance Rate',
#  u'Peer Percent of Range',
#  u'Peer 0% of Range',
#  u'Peer Average',
#  u'Peer 100% of Range',
#  u'City Percent of Range',
#  u'City 0% of Range',
#  u'City 100% of Range',
#  u'Metric Rating',
#  u'School Survey - Instructional Core',
#  u'Peer Percent of Range.1',
#  u'Peer 0% of Range.1',
#  u'Peer Average.1',
#  u'Peer 100% of Range.1',
#  u'City Percent of Range.1',
#  u'City 0% of Range.1',
#  u'City 100% of Range.1',
#  u'Metric Rating.1',
#  u'School Survey - School Culture',
#  u'Peer Percent of Range.2',
#  u'Peer 0% of Range.2',
#  u'Peer Average.2',
#  u'Peer 100% of Range.2',
#  u'City Percent of Range.2',
#  u'City 0% of Range.2',
#  u'City 100% of Range.2',
#  u'Metric Rating.2',
#  u'School Survey - Structures for Improvement',
#  u'Peer Percent of Range.3',
#  u'Peer 0% of Range.3',
#  u'Peer Average.3',
#  u'Peer 100% of Range.3',
# ...

# %%
sqr143 = pd.DataFrame(data=[sqr143['DBN'], sqr143['Attendance Rate'], sqr143['School Survey - School Culture']])
sqr143.head()
# Out:
#                                    0       1       2       3       4    \
# DBN                             01M292  01M448  01M450  01M509  01M539
# Attendance Rate                  0.707    0.86   0.915   0.775   0.949
# School Survey - School Culture   0.806   0.922   0.942    0.65   0.844
#
#                                    5       6       7       8       9    \
# DBN                             01M696  02M047  02M135  02M139  02M288
# Attendance Rate                  0.955   0.867   0.909   0.912    0.88
# School Survey - School Culture   0.926    0.85   0.935   0.897   0.866
#
#                                    10      11      12      13      14   \
# DBN                             02M294  02M296  02M298  02M300  02M303
# Attendance Rate                  0.868   0.824   0.924   0.812   0.813
# School Survey - School Culture    0.95   0.901   0.894   0.877   0.859
#
#                                    15      16      17      18      19   \
# ...

# %%
sqr143 = sqr143.transpose()

# %%
base14 = pd.merge(base14, sqr143, how='left', on=['DBN'])
base14.head()
# Out:
#       DBN Enrollment Average Grade 8 English Proficiency  \
# 0  01M292        258                               2.174
# 1  01M448        299                             2.22708
# 2  01M450        388                             2.66011
# 3  01M509        401                             2.34355
# 4  01M539        610                             3.48103
#
#   Average Grade 8 Math Proficiency     % ELL % Students with Disabilities  \
# 0                          2.07419  0.217054                     0.317829
# 1                          2.25908  0.280936                      0.29097
# 2                          2.58496  0.028351                     0.270619
# 3                          2.15377  0.082294                     0.276808
# 4                          3.48698  0.003279                     0.068852
#
#   % Self-Contained Percent Asian Percent Black Percent Hispanic Percent White  \
# 0         0.124031      0.143411      0.248062         0.554264      0.027132
# ...

# %%
base14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 484 entries, 0 to 483
# Data columns (total 46 columns):
# DBN                                                      484 non-null object
# Enrollment                                               478 non-null object
# Average Grade 8 English Proficiency                      478 non-null object
# Average Grade 8 Math Proficiency                         478 non-null object
# % ELL                                                    478 non-null object
# % Students with Disabilities                             478 non-null object
# % Self-Contained                                         478 non-null object
# Percent Asian                                            478 non-null object
# Percent Black                                            478 non-null object
# Percent Hispanic                                         478 non-null object
# Percent White                                            478 non-null object
# ...

# %%
# import longitudal demographics dataset
demo = pd.read_excel('2015 Graduation_Rates_Public_School-2.xlsx', sheetname=1, header=7)
demo.head()
# Out:
#                         Cohort Year Cohort Category  # #.1 % of cohort #.2  \
# 01M056 CORLEARS SCHOOL         2001    4 Year  June  1   s           s   s
#        CORLEARS SCHOOL         2001    5 Year  June  1   s           s   s
#        CORLEARS SCHOOL         2001          6 Year  1   s           s   s
#        CORLEARS SCHOOL         2003    4 Year  June  1   s           s   s
#        CORLEARS SCHOOL         2003    5 Year  June  1   s           s   s
#
#                        % of cohort.1 % of grads #.3 % of cohort.2  \
# 01M056 CORLEARS SCHOOL             s          s   s             s
#        CORLEARS SCHOOL             s          s   s             s
#        CORLEARS SCHOOL             s          s   s             s
#        CORLEARS SCHOOL             s          s   s             s
#        CORLEARS SCHOOL             s          s   s             s
#
#                        % of grads.1 #.4 % of cohort.3 % of grads.2 #.5  \
# ...

# %%
demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 17095 entries, (01M056, CORLEARS SCHOOL) to (32K564, BUSHWICK COMMUNITY HIGH SCHOOL)
# Data columns (total 21 columns):
# Cohort Year        17095 non-null int64
# Cohort Category    17095 non-null object
# #                  17095 non-null int64
# #.1                17095 non-null object
# % of cohort        17095 non-null object
# #.2                17095 non-null object
# % of cohort.1      17095 non-null object
# % of grads         17087 non-null object
# #.3                17095 non-null object
# % of cohort.2      17095 non-null object
# % of grads.1       17087 non-null object
# #.4                17095 non-null object
# % of cohort.3      17095 non-null object
# % of grads.2       17087 non-null object
# #.5                17095 non-null object
# % of cohort.4      17095 non-null object
# % of grads.3       17087 non-null object
# #.6                17095 non-null object
# % of cohort.5      17095 non-null object
# ...

# %%
# class of 2015
demo15 = demo[demo['Cohort Year']==2011]

# %%
# class of 2014
demo14 = demo[demo['Cohort Year']==2010]

# %%
demo15 = demo15[demo15['Cohort Category']=='4 Year August']
demo14 = demo14[demo14['Cohort Category']=='4 Year August']

# %%
demo15.head()
# Out:
#                                                       Cohort Year  \
# 01M292 HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES         2011
# 01M448 UNIVERSITY NEIGHBORHOOD HIGH SCHOOL                   2011
# 01M450 EAST SIDE COMMUNITY SCHOOL                            2011
# 01M458 FORSYTH SATELLITE ACADEMY                             2011
# 01M509 MARTA VALLE HIGH SCHOOL                               2011
#
#                                                      Cohort Category    # #.1  \
# 01M292 HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES   4 Year August   73  46
# 01M448 UNIVERSITY NEIGHBORHOOD HIGH SCHOOL             4 Year August   82  70
# 01M450 EAST SIDE COMMUNITY SCHOOL                      4 Year August   88  76
# 01M458 FORSYTH SATELLITE ACADEMY                       4 Year August   87  14
# 01M509 MARTA VALLE HIGH SCHOOL                         4 Year August  102  48
#
#                                                      % of cohort #.2  \
# ...

# %%
demo15 = demo15.reset_index()
demo14 = demo14.reset_index()

# %%
demo15.head()
# Out:
#   level_0                                        level_1  Cohort Year  \
# 0  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES         2011
# 1  01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL         2011
# 2  01M450                     EAST SIDE COMMUNITY SCHOOL         2011
# 3  01M458                      FORSYTH SATELLITE ACADEMY         2011
# 4  01M509                        MARTA VALLE HIGH SCHOOL         2011
#
#   Cohort Category    # #.1 % of cohort #.2 % of cohort.1 % of grads #.3  \
# 0   4 Year August   73  46    0.630137  41      0.561644   0.891304   0
# 1   4 Year August   82  70    0.853659  59      0.719512   0.842857  13
# 2   4 Year August   88  76    0.863636  75      0.852273   0.986842   0
# 3   4 Year August   87  14     0.16092  12      0.137931   0.857143   0
# 4   4 Year August  102  48    0.470588  41      0.401961   0.854167   5
#
#   % of cohort.2 % of grads.1 #.4 % of cohort.3 % of grads.2 #.5 % of cohort.4  \
# ...

# %%
demo15 = demo15.rename(columns=({ 'level_0' : 'DBN', '% of cohort.6': 'dropouts_percent'}))
demo14 = demo14.rename(columns=({ 'level_0' : 'DBN', '% of cohort.6': 'dropouts_percent'}))

# %%
demo15 = pd.DataFrame(data=[demo15['DBN'], demo15['dropouts_percent']])
demo14 = pd.DataFrame(data=[demo14['DBN'], demo14['dropouts_percent']])

# %%
demo15 = demo15.transpose()
demo14 = demo14.transpose()

# %%
base15 = pd.merge(base15, demo15, how='left', on=['DBN'])
base14 = pd.merge(base14, demo14, how='left', on=['DBN'])

# %%
base15.head()
# Out:
#       DBN Enrollment Supportive Environment - Percent Positive  \
# 0  01M292        255                                      0.77
# 1  01M448        304                                      0.87
# 2  01M450        666                                      0.92
# 3  01M509        363                                      0.81
# 4  01M539       1735                                      0.85
#
#   Average Grade 8 English Proficiency Average Grade 8 Math Proficiency  \
# 0                                2.18                             2.06
# 1                                2.27                             2.37
# 2                                2.66                             2.63
# 3                                2.28                             2.09
# 4                                 3.5                             3.53
#
#   Percent English Language Learners Percent Students with Disabilities  \
# 0                             0.127                              0.298
# ...

# %%
# import longitudal demographic snapshot
snap = pd.read_excel('DemographicSnapshot201011to201415Public_FINAL-2.xlsx', sheetname=3, header=0)
snap.head()
# Out:
#       DBN                School Name     Year  Total Enrollment  Grade PK  \
# 0  01M015  P.S. 015 Roberto Clemente  2010-11               203        13
# 1  01M015  P.S. 015 Roberto Clemente  2011-12               189        13
# 2  01M015  P.S. 015 Roberto Clemente  2012-13               177        18
# 3  01M015  P.S. 015 Roberto Clemente  2013-14               190        26
# 4  01M015  P.S. 015 Roberto Clemente  2014-15               183        18
#
#    Grade K  Grade 1  Grade 2  Grade 3  Grade 4  Grade 5  Grade 6  Grade 7  \
# 0       37       35       33       30       30       25        0        0
# 1       31       35       28       25       28       29        0        0
# 2       38       26       22       26       23       24        0        0
# 3       39       39       21       16       26       23        0        0
# 4       27       47       31       19       17       24        0        0
#
# ...

# %%
snap15 = snap[snap['Year']=='2014-15']
snap14 = snap[snap['Year']=='2013-14']

# %%
snap15 = pd.DataFrame(data=[snap15['DBN'], snap15['% Male'], snap15['% Female'], snap15['% Poverty']])
snap14 = pd.DataFrame(data=[snap14['DBN'], snap14['% Male'], snap14['% Female'], snap14['% Poverty']])

# %%
snap15 = snap15.transpose()
snap14 = snap14.transpose()

# %%
base15 = pd.merge(base15, snap15, how='left', on=['DBN'])
base14 = pd.merge(base14, snap14, how='left', on=['DBN'])

# %%
# I forgot to add graduation rates! - from sqr
grad15 = pd.read_excel('2014_2015_HS_SQR_Results_2016_01_07.xlsx', sheetname=1, header=1)
grad14 = pd.read_excel('2013_2014_HS_SQR_Results_2015_03_02.xlsx', sheetname=2, header=1)

# %%
list(grad14)
# Out:
# [u'DBN',
#  u'School Name',
#  u'Achievement Score',
#  u'Achievement Rating',
#  u'Four Year Graduation Rate',
#  u'Number of Students',
#  u'Peer 0% of Range',
#  u'Peer Average',
#  u'Peer 100% of Range',
#  u'Peer Percent of Range',
#  u'City 0% of Range',
#  u'City 100% of Range',
#  u'City Percent of Range',
#  u'Metric Rating',
#  u'Borough Average',
#  u'City Average',
#  u'Six Year Graduation Rate',
#  u'Number of Students.1',
#  u'Peer 0% of Range.1',
#  u'Peer Average.1',
#  u'Peer 100% of Range.1',
#  u'Peer Percent of Range.1',
#  u'City 0% of Range.1',
#  u'City 100% of Range.1',
#  u'City Percent of Range.1',
#  u'Metric Rating.1',
#  u'Borough Average.1',
#  u'City Average.1',
#  u'Four Year Weighted Diploma Rate',
#  u'Number of Students.2',
#  u'Peer 0% of Range.2',
#  u'Peer Average.2',
#  u'Peer 100% of Range.2',
#  u'Peer Percent of Range.2',
#  u'City 0% of Range.2',
#  u'City 100% of Range.2',
#  u'City Percent of Range.2',
#  u'Metric Rating.2',
# ...

# %%
list(grad15)
# Out:
# [u'DBN',
#  u'School Name',
#  u'Student Achievement - Section Rating',
#  u'Student Achievement - Section Score',
#  u'Metric Rating - Percentage Earning 10+ Credits in First Year',
#  u'Metric Value - Percentage Earning 10+ Credits in First Year',
#  u'Approaching Target For 2015 - Percentage Earning 10+ Credits in First Year',
#  u'Meeting Target For 2015 - Percentage Earning 10+ Credits in First Year',
#  u'Exceeding Target For 2015 - Percentage Earning 10+ Credits in First Year',
#  u'Metric Score - Percentage Earning 10+ Credits in First Year',
#  u'Metric Rating - Lowest Third School, Percentage Earning 10+ Credits in First Year',
#  u'Metric Value - Lowest Third School, Percentage Earning 10+ Credits in First Year',
#  u'Approaching Target For 2015 - Lowest Third School, Percentage Earning 10+ Credits in First Year',
#  u'Meeting Target For 2015 - Lowest Third School, Percentage Earning 10+ Credits in First Year',
# ...

# %%
grad14 = pd.DataFrame(data=[grad14['DBN'], grad14['Four Year Graduation Rate']])
grad15 = pd.DataFrame(data=[grad15['DBN'], grad15['Metric Value - Graduation Rate, 4 year']])

# %%
grad15 = grad15.transpose()
grad14 = grad14.transpose()

# %%
base15 = pd.merge(base15, grad15, how='left', on=['DBN'])
base14 = pd.merge(base14, grad14, how='left', on=['DBN'])

# %%
base15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 0 to 490
# Data columns (total 53 columns):
# DBN                                                               491 non-null object
# Enrollment                                                        491 non-null object
# Supportive Environment - Percent Positive                         491 non-null object
# Average Grade 8 English Proficiency                               491 non-null object
# Average Grade 8 Math Proficiency                                  491 non-null object
# Percent English Language Learners                                 491 non-null object
# Percent Students with Disabilities                                491 non-null object
# Percent Self-Contained                                            491 non-null object
# Percent Asian                                                     491 non-null object
# Percent Black                                                     491 non-null object
# ...

# %%
# read high school directories
dir14 = pd.read_csv('DOE_High_School_Directory_2013-2014.csv')
dir15 = pd.read_csv('DOE_High_School_Directory_2014-2015.csv')

# %%
dir15.head()
# Out:
#       dbn                                        school_name       boro  \
# 0  01M292      Henry Street School for International Studies  Manhattan
# 1  01M448                University Neighborhood High School  Manhattan
# 2  01M450                         East Side Community School  Manhattan
# 3  01M509                            Marta Valle High School  Manhattan
# 4  01M539  New Explorations into Science, Technology and ...  Manhattan
#
#   building_code  phone_number    fax_number grade_span_min  grade_span_max  \
# 0          M056  212-406-9411  212-406-9417              6              12
# 1          M446  212-962-4341  212-267-5611              9              12
# 2          M060  212-460-8467  212-260-9657              6              12
# 3          M025  212-473-8152  212-475-7588              9              12
# 4          M022  212-677-5190  212-260-8124              K              12
#
#   expgrade_span_min  expgrade_span_max  \
# ...

# %%
dir15 = dir15.rename(columns=({ 'dbn' : 'DBN'}))

# %%
list(dir15)
# Out:
# ['DBN',
#  'school_name',
#  'boro',
#  'building_code',
#  'phone_number',
#  'fax_number',
#  'grade_span_min',
#  'grade_span_max',
#  'expgrade_span_min',
#  'expgrade_span_max',
#  'bus',
#  'subway',
#  'primary_address_line_1',
#  'city',
#  'state_code',
#  'zip',
#  'website',
#  'total_students',
#  'campus_name',
#  'school_type',
#  'overview_paragraph',
#  'program_highlights',
#  'language_classes',
#  'advancedplacement_courses',
#  'online_ap_courses',
#  'online_language_courses',
#  'extracurricular_activities',
#  'psal_sports_boys',
#  'psal_sports_girls',
#  'psal_sports_coed',
#  'school_sports',
#  'partner_cbo',
#  'partner_hospital',
#  'partner_highered',
#  'partner_cultural',
#  'partner_nonprofit',
#  'partner_corporate',
#  'partner_financial',
#  'partner_other',
#  'addtl_info1',
#  'addtl_info2',
#  'start_time',
#  'end_time',
#  'se_services',
#  'ell_programs',
#  'school_accessibility_description',
#  'number_programs',
#  'priority01',
# ...

# %%
list(dir14)
# Out:
# ['DBN',
#  'Boro',
#  'BN',
#  'Building Code',
#  'School_Phone_Number',
#  'Fax_Number',
#  'Printed_Name',
#  'Alphabetic_Name_Long',
#  'grade span 2014-2015 min',
#  'grade span 2014-2015 max',
#  'Expected grade span min',
#  'Expected grade span max',
#  'Last Year BUS?',
#  'BUS',
#  'Last Year SUBWAY?',
#  'SUBWAY',
#  'Primary_Address_Line_1',
#  'City',
#  'State_Code',
#  'Zip',
#  'Total Student 10/26',
#  'Campus_Name',
#  'ELL Data',
#  'School_Accessibility_Description',
#  'First Priority01',
#  'Second Priority02',
#  'Third Priority03',
#  'Fourth Priority04',
#  'Fifth Priority05',
#  'Sixth Priority06',
#  'Seventh Priority07',
#  'Eighth Priority08',
#  'Ninth Priority09',
#  'Tenth Priority10',
#  'Eleventh Priority11',
#  'progcount',
#  'Email',
#  'Independent Website',
#  'School_Type',
#  'Overview Paragraph',
#  'Program Highlights',
#  'Language Classes',
#  'Advanced Placement Courses',
#  'Extra_Leadership&Support',
#  'PSAL Sports - Boys',
# ...

# %%
dir15 = pd.DataFrame(data=[dir15['DBN'], dir15['start_time'], dir15['end_time'], dir15['school_type'], dir14['precinct']])
dir14 = pd.DataFrame(data=[dir14['DBN'], dir14['Start Time'], dir14['End Time'], dir14['School_Type2'], dir14['precinct']])

# %%
dir15 = dir15.transpose()
dir14 = dir14.transpose()

# %%
base15 = pd.merge(base15, dir15, how='left', on=['DBN'])
base14 = pd.merge(base14, dir14, how='left', on=['DBN'])

# %%
# add location info; may be helpful for explanations later
locate = pd.read_csv('Location_Information_Report.csv')
locate.head()
# Out:
#   School Year ATS System Code Location Code                   Location Name  \
# 0     2015-16          01M015          M015       P.S. 015 Roberto Clemente
# 1     2015-16          01M019          M019             P.S. 019 Asher Levy
# 2     2015-16          01M020          M020            P.S. 020 Anna Silver
# 3     2015-16          01M034          M034  P.S. 034 Franklin D. Roosevelt
# 4     2015-16          01M063          M063       The STAR Academy - P.S.63
#
#     BEDS Number Managed By Name Location Type Description  \
# 0  3.101000e+11             DOE          General Academic
# 1  3.101000e+11             DOE          General Academic
# 2  3.101000e+11             DOE          General Academic
# 3  3.101000e+11             DOE          General Academic
# 4  3.101000e+11             DOE          General Academic
#
#   Location Category Description                            Grades  \
# 0                    Elementary              PK,01,02,03,04,05,SE
# ...

# %%
locate = locate.rename(columns=({ 'ATS System Code' : 'DBN'}))
locate15 = pd.DataFrame(data=[locate['DBN'], locate['Zip'], locate['Geographical District Code'], locate['Administrative District Code']])      
locate14 = pd.DataFrame(data=[locate['DBN'], locate['Zip'], locate['Geographical District Code'], locate['Administrative District Code']])

# %%
locate15 = locate15.transpose()
locate14 = locate14.transpose()

# %%
base15 = pd.merge(base15, locate15, how='left', on=['DBN'])
base14 = pd.merge(base14, locate14, how='left', on=['DBN'])

# %%
base15['class_grad_year'] = 2015
base14['class_grad_year'] = 2014

# %%
home = pd.read_csv('Zip_MedianValuePerSqft_AllHomes.csv')
home.head()
# Out:
#    RegionID  RegionName      City State                               Metro  \
# 0     62080       11368  New York    NY                            New York
# 1     93144       79936   El Paso    TX                             El Paso
# 2     84630       60629   Chicago    IL                             Chicago
# 3     96193       90650   Norwalk    CA  Los Angeles-Long Beach-Anaheim, CA
# 4     62037       11226  New York    NY                            New York
#
#     CountyName  SizeRank  1996-04  1996-05  1996-06  1996-07  1996-08  \
# 0       Queens         1      NaN      NaN      NaN      NaN      NaN
# 1      El Paso         2       50       51       50       50       50
# 2         Cook         3       83       83       83       83       84
# 3  Los Angeles         4      116      116      116      115      114
# 4        Kings         5      NaN      NaN      NaN      NaN      NaN
#
#    1996-09  1996-10  1996-11  1996-12  1997-01  1997-02  1997-03  1997-04  \
# ...

# %%
home.tail()
# Out:
#        RegionID  RegionName             City State       Metro CountyName  \
# 13159    100099       99123    Electric City    WA  Moses Lake      Grant
# 13160    100186       99326          Connell    WA   Kennewick   Franklin
# 13161    399732       86315  Prescott Valley    AZ    Prescott    Yavapai
# 13162    417445       85145           Marana    AZ      Tucson       Pima
# 13163    417461       85123      Casa Grande    AZ     Phoenix      Pinal
#
#        SizeRank  1996-04  1996-05  1996-06  1996-07  1996-08  1996-09  \
# 13159     13160       55       55       55       55       53       51
# 13160     13161       59       61       61       62       62       63
# 13161     13162       59       59       59       60       59       59
# 13162     13163      NaN      NaN      NaN      NaN      NaN      NaN
# 13163     13164       47       47       48       48       49       49
#
#        1996-10  1996-11  1996-12  1997-01  1997-02  1997-03  1997-04  1997-05  \
# ...

# %%
list(home)
# Out:
# ['RegionID',
#  'RegionName',
#  'City',
#  'State',
#  'Metro',
#  'CountyName',
#  'SizeRank',
#  '1996-04',
#  '1996-05',
#  '1996-06',
#  '1996-07',
#  '1996-08',
#  '1996-09',
#  '1996-10',
#  '1996-11',
#  '1996-12',
#  '1997-01',
#  '1997-02',
#  '1997-03',
#  '1997-04',
#  '1997-05',
#  '1997-06',
#  '1997-07',
#  '1997-08',
#  '1997-09',
#  '1997-10',
#  '1997-11',
#  '1997-12',
#  '1998-01',
#  '1998-02',
#  '1998-03',
#  '1998-04',
#  '1998-05',
#  '1998-06',
#  '1998-07',
#  '1998-08',
#  '1998-09',
#  '1998-10',
#  '1998-11',
#  '1998-12',
#  '1999-01',
#  '1999-02',
#  '1999-03',
#  '1999-04',
#  '1999-05',
#  '1999-06',
#  '1999-07',
#  '1999-08',
#  '1999-09',
#  '1999-10',
#  '1999-11',
#  '1999-12',
#  '2000-01',
#  '2000-02',
#  '2000-03',
#  '2000-04',
#  '2000-05',
#  '2000-06',
#  '2000-07',
#  '2000-08',
#  '2000-09',
#  '2000-10',
#  '2000-11',
#  '2000-12',
#  '2001-01',
#  '2001-02',
#  '2001-03',
#  '2001-04',
#  '2001-05',
#  '2001-06',
#  '2001-07',
# ...

# %%
h2015 = home.loc[:,'2015-01':'2015-12']
h2015['2015_avg_home_value_sqft'] = h2015.mean(axis=1)

# %%
h2014 = home.loc[:,'2014-01':'2014-12']
h2014['2014_avg_home_value_sqft'] = h2014.mean(axis=1)

# %%
h2015.head()
# Out:
#    2015-01  2015-02  2015-03  2015-04  2015-05  2015-06  2015-07  2015-08  \
# 0      457      459      461      463      466      468      468      466
# 1       79       79       79       79       79       79       79       80
# 2      120      120      119      119      119      120      122      124
# 3      308      311      314      316      318      319      321      324
# 4      447      448      447      446      447      450      454      458
#
#    2015-09  2015-10  2015-11  2015-12  2015_avg_home_value_sqft
# 0      468      478      485      487                468.833333
# 1       80       80       80       79                 79.333333
# 2      124      124      123      124                121.500000
# 3      325      326      327      329                319.833333
# 4      460      459      461      466                453.583333

# %%
havg2015 = pd.DataFrame(data=[h2015['2015_avg_home_value_sqft']])

# %%
havg2014 = pd.DataFrame(data=[h2014['2014_avg_home_value_sqft']])
havg2014 = havg2014.transpose()

# %%
havg2015 = havg2015.transpose()

# %%
havg2015.head()
# Out:
#    2015_avg_home_value_sqft
# 0                468.833333
# 1                 79.333333
# 2                121.500000
# 3                319.833333
# 4                453.583333

# %%
havg2014.head()
# Out:
#    2014_avg_home_value_sqft
# 0                433.583333
# 1                 79.750000
# 2                118.666667
# 3                300.666667
# 4                412.500000

# %%
home15 = pd.DataFrame(data=[home['RegionName']])
home15 = home15.transpose()

# %%
home14 = pd.DataFrame(data=[home['RegionName']])
home14 = home14.transpose()

# %%
home15.head()
# Out:
#    RegionName
# 0       11368
# 1       79936
# 2       60629
# 3       90650
# 4       11226

# %%
home14.head()
# Out:
#    RegionName
# 0       11368
# 1       79936
# 2       60629
# 3       90650
# 4       11226

# %%
homebase2015 = pd.concat([home15, havg2015], axis=1)

# %%
homebase2014 = pd.concat([home14, havg2014], axis=1)

# %%
homebase2015.head()
# Out:
#    RegionName  2015_avg_home_value_sqft
# 0       11368                468.833333
# 1       79936                 79.333333
# 2       60629                121.500000
# 3       90650                319.833333
# 4       11226                453.583333

# %%
homebase2015 = pd.DataFrame(data=[homebase2015['RegionName'], homebase2015['2015_avg_home_value_sqft']])

# %%
homebase2014 = pd.DataFrame(data=[homebase2014['RegionName'], homebase2014['2014_avg_home_value_sqft']])

# %%
homebase2015 = homebase2015.transpose()

# %%
homebase2014 = homebase2014.transpose()

# %%
homebase2015.head()
# Out:
#    RegionName  2015_avg_home_value_sqft
# 0       11368                468.833333
# 1       79936                 79.333333
# 2       60629                121.500000
# 3       90650                319.833333
# 4       11226                453.583333

# %%
homebase2014.head()
# Out:
#    RegionName  2014_avg_home_value_sqft
# 0       11368                433.583333
# 1       79936                 79.750000
# 2       60629                118.666667
# 3       90650                300.666667
# 4       11226                412.500000

# %%
homebase2015 = homebase2015.rename(columns=({'RegionName' : 'Zip',}))
homebase2014 = homebase2014.rename(columns=({'RegionName' : 'Zip',}))

# %%
base2015 = base15.copy()
base2014 = base14.copy()

# %%
base15 = pd.merge(base15, homebase2015, how='left', on=['Zip'])
base14 = pd.merge(base14, homebase2014, how='left', on=['Zip'])

# %%
home[home['RegionName']==10019]
# Out:
# Empty DataFrame
# Columns: [RegionID, RegionName, City, State, Metro, CountyName, SizeRank, 1996-04, 1996-05, 1996-06, 1996-07, 1996-08, 1996-09, 1996-10, 1996-11, 1996-12, 1997-01, 1997-02, 1997-03, 1997-04, 1997-05, 1997-06, 1997-07, 1997-08, 1997-09, 1997-10, 1997-11, 1997-12, 1998-01, 1998-02, 1998-03, 1998-04, 1998-05, 1998-06, 1998-07, 1998-08, 1998-09, 1998-10, 1998-11, 1998-12, 1999-01, 1999-02, 1999-03, 1999-04, 1999-05, 1999-06, 1999-07, 1999-08, 1999-09, 1999-10, 1999-11, 1999-12, 2000-01, 2000-02, 2000-03, 2000-04, 2000-05, 2000-06, 2000-07, 2000-08, 2000-09, 2000-10, 2000-11, 2000-12, 2001-01, 2001-02, 2001-03, 2001-04, 2001-05, 2001-06, 2001-07, 2001-08, 2001-09, 2001-10, 2001-11, 2001-12, 2002-01, 2002-02, 2002-03, 2002-04, 2002-05, 2002-06, 2002-07, 2002-08, 2002-09, 2002-10, 2002-11, 2002-12, 2003-01, 2003-02, 2003-03, 2003-04, 2003-05, 2003-06, 2003-07, 2003-08, 2003-09, 2003-10, 2003-11, 2003-12, ...]
# Index: []

# %%
list(base15)
# Out:
# [u'DBN',
#  u'Enrollment',
#  u'Supportive Environment - Percent Positive',
#  u'Average Grade 8 English Proficiency',
#  u'Average Grade 8 Math Proficiency',
#  u'Percent English Language Learners',
#  u'Percent Students with Disabilities',
#  u'Percent Self-Contained',
#  u'Percent Asian',
#  u'Percent Black',
#  u'Percent Hispanic',
#  u'Percent White',
#  u'Years of principal experience at this school',
#  u'Student Attendance Rate',
#  u'Teacher Attendance Rate',
#  u'School Name',
#  u'Average Score Regents Algebra',
#  u'Average Score Regents Geometry',
#  u'Average Score Regents Algebra 2/Trig',
#  u'Average Score Regents English',
#  u'Average Score Regents US History',
#  u'Average Score Regents Global History',
#  u'Average Score Regents Chemistry',
#  u'Average Score Regents Physics',
#  u'Average Score Regents Earth Science',
#  u'Average Score Regents Living Environment',
#  u'Average Score Regents Languages Other Than English',
#  u'Average Score SAT Math',
# ...

# %%
list(base14)
# Out:
# [u'DBN',
#  u'Enrollment',
#  u'Average Grade 8 English Proficiency',
#  u'Average Grade 8 Math Proficiency',
#  u'% ELL',
#  u'% Students with Disabilities',
#  u'% Self-Contained',
#  u'Percent Asian',
#  u'Percent Black',
#  u'Percent Hispanic',
#  u'Percent White',
#  u'Years of Principal Experience at This School',
#  u'Teacher Attendance',
#  u'School Name',
#  u'Average Score Regents Integrated Algebra',
#  u'Average Score Regents Geometry',
#  u'Average Score Regents Algebra 2/Trig',
#  u'Average Score Regents English',
#  u'Average Score Regents US History',
#  u'Average Score Regents Global History',
#  u'Average Score Regents Chemistry',
#  u'Average Score Regents Physics',
#  u'Average Score Regents Earth Science',
#  u'Average Score Regents Living Environment',
#  u'Average Score Regents Languages Other Than English',
#  u'Average Score SAT Math',
#  u'% of 4-year Cohort Taking SAT Math',
#  u'Average Score SAT Critical Reading',
#  u'Average Score SAT Writing',
# ...

# %%
base14 = base14.rename(columns=({ '% ELL' : 'Percent English Language Learners', '% Students with Disabilities': 'Percent Students with Disabilities',
                                '% Self-Contained' : 'Percent Self-Contained', '% earning a diploma with a CTE Endorsement': 'Percentage Earning a Diploma with a CTE Endorsement',
                                '% passing an industry-recognized technical assessment': 'Percentage Passing an Industry-Recognized Technical Assessment', '% earning a diploma with an Arts endorsement': 'Percentage Earning a Diploma with an Arts Endorsement',
                                'School Survey - School Culture': 'Supportive Environment - Percent Positive', 'CRI (% of 4 year Cohort)': 'CRI (Percentage of 4 year Cohort)',
                                'Start Time': 'start_time', 'End Time': 'end_time',
                                'School_Type2': 'school_type', '2014_avg_home_value_sqft': '2015_avg_home_value_sqft',
                                'Average Score Regents Integrated Algebra':'Average Score Regents Algebra',
                                '% scoring 3+ on any AP exam': 'Percentage Scoring 3+ on any AP Exam'}))

# %%
# import student ratio/class size data - 2015
ratio15 = pd.read_excel('SchoolLevelDetailSummaryPreliminary2015.xlsx', sheetname=0, header=10)
ratio15.head()
# Out:
#   BORO  CSD SCHOOL CODE                SCHOOL NAME GRADE  PROGRAM TYPE  \
# 0    M    1        M015  P.S. 015 ROBERTO CLEMENTE     0K          ICT
# 1    M    1        M015  P.S. 015 ROBERTO CLEMENTE     0K          G&T
# 2    M    1        M015  P.S. 015 ROBERTO CLEMENTE     01       GEN ED
# 3    M    1        M015  P.S. 015 ROBERTO CLEMENTE     01          ICT
# 4    M    1        M015  P.S. 015 ROBERTO CLEMENTE     01          G&T
#
#   CORE SUBJECT \n(MS CORE and \n9-12 ONLY)  \
# 0                                        -
# 1                                        -
# 2                                        -
# 3                                        -
# 4                                        -
#
#   CORE COURSE \n(MS CORE and 9-12 ONLY) SERVICE CATEGORY\n(K-8 ONLY)  \
# 0                                     -                            -
# 1                                     -                            -
# ...

# %%
ratio14 = pd.read_excel('Updated_School_level_Detail_Summary_2014_02_13.xlsx', sheetname=0, header=10)
ratio14.tail()
# Out:
#       BORO  CSD SCHOOL CODE                     SCHOOL NAME GRADE   \
# 30957    K   32        K564  BUSHWICK COMMUNITY HIGH SCHOOL  09-12
# 30958    K   32        K564  BUSHWICK COMMUNITY HIGH SCHOOL  09-12
# 30959    K   32        K564  BUSHWICK COMMUNITY HIGH SCHOOL  09-12
# 30960    K   32        K564  BUSHWICK COMMUNITY HIGH SCHOOL  09-12
# 30961    K   32        K564  BUSHWICK COMMUNITY HIGH SCHOOL    NaN
#
#       PROGRAM TYPE CORE SUBJECT \n(MS CORE and \n9-12 ONLY)  \
# 30957          CTT                                  English
# 30958          CTT                                  English
# 30959          CTT                                  English
# 30960          CTT                                     Math
# 30961          NaN                                      NaN
#
#       CORE COURSE \n(MS CORE and 9-12 ONLY) SERVICE CATEGORY\n(K-9* ONLY)  \
# 30957                            English 10                             -
# ...

# %%
# School Code is unlike DBN, so will try to join using school name
ratio15['SCHOOLWIDE PUPIL-TEACHER RATIO'] = ratio15['SCHOOLWIDE PUPIL-TEACHER RATIO'].notnull()
ratio15pd = pd.DataFrame(data=[ratio15.groupby(ratio15['SCHOOL NAME'], sort=True)['SCHOOLWIDE PUPIL-TEACHER RATIO'].mean()])
ratio15pd = ratio15pd.transpose()
ratio15pd.head()
# Out:
#                                                     SCHOOLWIDE PUPIL-TEACHER RATIO
# SCHOOL NAME
# 47 The American Sign Language and English Secon...                        0.035714
# A. PHILIP RANDOLPH CAMPUS HIGH SCHOOL                                     0.027027
# A.C.E. Academy for Scholars at the Geraldine Fe...                        0.062500
# ABRAHAM LINCOLN HIGH SCHOOL                                               0.022222
# ACADEMY FOR ENVIRONMENTAL LEADERSHIP                                      0.027778

# %%
ratio14['SCHOOLWIDE PUPIL-TEACHER RATIO'] = ratio14['SCHOOLWIDE PUPIL-TEACHER RATIO'].notnull()
ratio14pd = pd.DataFrame(data=[ratio14.groupby(ratio14['SCHOOL NAME'], sort=True)['SCHOOLWIDE PUPIL-TEACHER RATIO'].mean()])
ratio14pd = ratio14pd.transpose()
ratio14pd.head()
# Out:
#                                                     SCHOOLWIDE PUPIL-TEACHER RATIO
# SCHOOL NAME
# 47 The American Sign Language and English Secon...                        0.041667
# A. PHILIP RANDOLPH CAMPUS HIGH SCHOOL                                     0.026316
# A.C.E. Academy for Scholars at the Geraldine Fe...                        0.076923
# ABRAHAM LINCOLN HIGH SCHOOL                                               0.022222
# ACADEMY FOR ENVIRONMENTAL LEADERSHIP                                      0.031250

# %%
ratio15pd = ratio15pd.reset_index()
ratio15pd.head()
# Out:
#                                          SCHOOL NAME  \
# 0  47 The American Sign Language and English Seco...
# 1              A. PHILIP RANDOLPH CAMPUS HIGH SCHOOL
# 2  A.C.E. Academy for Scholars at the Geraldine F...
# 3                        ABRAHAM LINCOLN HIGH SCHOOL
# 4               ACADEMY FOR ENVIRONMENTAL LEADERSHIP
#
#    SCHOOLWIDE PUPIL-TEACHER RATIO
# 0                        0.035714
# 1                        0.027027
# 2                        0.062500
# 3                        0.022222
# 4                        0.027778

# %%
ratio14pd = ratio14pd.reset_index()
ratio14pd.head()
# Out:
#                                          SCHOOL NAME  \
# 0  47 The American Sign Language and English Seco...
# 1              A. PHILIP RANDOLPH CAMPUS HIGH SCHOOL
# 2  A.C.E. Academy for Scholars at the Geraldine F...
# 3                        ABRAHAM LINCOLN HIGH SCHOOL
# 4               ACADEMY FOR ENVIRONMENTAL LEADERSHIP
#
#    SCHOOLWIDE PUPIL-TEACHER RATIO
# 0                        0.041667
# 1                        0.026316
# 2                        0.076923
# 3                        0.022222
# 4                        0.031250

# %%
ratio15pd = ratio15pd.rename(columns=({ 'SCHOOL NAME' : 'School Name', 'SCHOOLWIDE PUPIL-TEACHER RATIO': 'pupil_teacher_ratio',}))
ratio15pd.head()
# Out:
#                                          School Name  pupil_teacher_ratio
# 0  47 The American Sign Language and English Seco...             0.035714
# 1              A. PHILIP RANDOLPH CAMPUS HIGH SCHOOL             0.027027
# 2  A.C.E. Academy for Scholars at the Geraldine F...             0.062500
# 3                        ABRAHAM LINCOLN HIGH SCHOOL             0.022222
# 4               ACADEMY FOR ENVIRONMENTAL LEADERSHIP             0.027778

# %%
ratio14pd = ratio14pd.rename(columns=({ 'SCHOOL NAME' : 'School Name', 'SCHOOLWIDE PUPIL-TEACHER RATIO': 'pupil_teacher_ratio',}))
ratio14pd.head()
# Out:
#                                          School Name  pupil_teacher_ratio
# 0  47 The American Sign Language and English Seco...             0.041667
# 1              A. PHILIP RANDOLPH CAMPUS HIGH SCHOOL             0.026316
# 2  A.C.E. Academy for Scholars at the Geraldine F...             0.076923
# 3                        ABRAHAM LINCOLN HIGH SCHOOL             0.022222
# 4               ACADEMY FOR ENVIRONMENTAL LEADERSHIP             0.031250

# %%
# all other DBNs start with 01 except this dataset's! This did not help, which is why I used school name
#ratio15pd['DBN'] = '0'+ ratio15['CSD'].astype('str')
#ratio14pd['DBN'] = '0'+ ratio14['CSD'].astype('str')
#ratio15pd.head()

# %%
#ratio15pd['DBN'] = ratio15pd['DBN'][0:-2] + ratio15['SCHOOL CODE']
#ratio14pd['DBN'] = ratio14pd['DBN'][0:-2] + ratio14['SCHOOL CODE']
#ratio15pd.head()

# %%
base15 = pd.merge(base15, ratio15pd, how='left', on=['School Name'])
base15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 0 to 490
# Data columns (total 63 columns):
# DBN                                                               491 non-null object
# Enrollment                                                        491 non-null object
# Supportive Environment - Percent Positive                         491 non-null object
# Average Grade 8 English Proficiency                               491 non-null object
# Average Grade 8 Math Proficiency                                  491 non-null object
# Percent English Language Learners                                 491 non-null object
# Percent Students with Disabilities                                491 non-null object
# Percent Self-Contained                                            491 non-null object
# Percent Asian                                                     491 non-null object
# Percent Black                                                     491 non-null object
# ...

# %%
base14 = pd.merge(base14, ratio14pd, how='left', on=['School Name'])
base14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 484 entries, 0 to 483
# Data columns (total 61 columns):
# DBN                                                               484 non-null object
# Enrollment                                                        478 non-null object
# Average Grade 8 English Proficiency                               478 non-null object
# Average Grade 8 Math Proficiency                                  478 non-null object
# Percent English Language Learners                                 478 non-null object
# Percent Students with Disabilities                                478 non-null object
# Percent Self-Contained                                            478 non-null object
# Percent Asian                                                     478 non-null object
# Percent Black                                                     478 non-null object
# Percent Hispanic                                                  478 non-null object
# ...

# %%
# look at major crimes
crimemaj15 = pd.read_excel('seven_major_felony_offenses_by_precinct_2000_2014.xls', sheetname=0, header=2)
crimemaj15.head(20)
# Out:
#     PCT                                              CRIME  2000  2001  2002  \
# 0     1  MURDER & NON NEGL. MANSLAUGHTER               ...     3     1     2
# 1   NaN             RAPE                                      12     5    10
# 2   NaN             ROBBERY                                  252   188   210
# 3   NaN             FELONY ASSAULT                           139   164   147
# 4   NaN             BURGLARY                                 475   437   297
# 5   NaN             GRAND LARCENY                           2358  2117  1896
# 6   NaN  GRAND LARCENY OF MOTOR VEHICLE                ...   199   157   153
# 7   NaN                  TOTAL SEVEN MAJOR FELONY OFFENSES  3438  3069  2715
# 8     5  MURDER & NON NEGL. MANSLAUGHTER               ...     4     3     0
# 9   NaN             RAPE                                       9     3    12
# 10  NaN             ROBBERY                                  351   261   196
# ...

# %%
# look at violation offenses
crimemin15 = pd.read_excel('violation-offenses-by-precinct_2000-2014.xls', sheetname=0, header=2)
crimemin15.head(20)
# Out:
#     PCT                                   CRIME  2000  2001  2002  2003  2004  \
# 0     1  HARASSMENT 2                             971   859   806   760   705
# 1   NaN                    OTHER VIOLATIONS (1)    91    49    59    59    81
# 2   NaN                TOTAL VIOLATION OFFENSES  1062   908   865   819   786
# 3     5  HARASSMENT 2                             524   533   506   481   383
# 4   NaN                    OTHER VIOLATIONS (1)    47    30    92    26    13
# 5   NaN                TOTAL VIOLATION OFFENSES   571   563   598   507   396
# 6     6  HARASSMENT 2                             776   752   663   527   485
# 7   NaN                    OTHER VIOLATIONS (1)    70    62    49    69    26
# 8   NaN                TOTAL VIOLATION OFFENSES   846   814   712   596   511
# 9     7  HARASSMENT 2                             585   534   513   480   427
# 10  NaN                    OTHER VIOLATIONS (1)     9    13    21    20    13
# ...

# %%
crimemin15 = crimemin15.fillna(method='ffill')
crimemin15.head(20)
# Out:
#    PCT                                   CRIME  2000  2001  2002  2003  2004  \
# 0    1  HARASSMENT 2                             971   859   806   760   705
# 1    1                    OTHER VIOLATIONS (1)    91    49    59    59    81
# 2    1                TOTAL VIOLATION OFFENSES  1062   908   865   819   786
# 3    5  HARASSMENT 2                             524   533   506   481   383
# 4    5                    OTHER VIOLATIONS (1)    47    30    92    26    13
# 5    5                TOTAL VIOLATION OFFENSES   571   563   598   507   396
# 6    6  HARASSMENT 2                             776   752   663   527   485
# 7    6                    OTHER VIOLATIONS (1)    70    62    49    69    26
# 8    6                TOTAL VIOLATION OFFENSES   846   814   712   596   511
# 9    7  HARASSMENT 2                             585   534   513   480   427
# 10   7                    OTHER VIOLATIONS (1)     9    13    21    20    13
# ...

# %%
crimemaj15 = crimemaj15.fillna(method='ffill')
crimemaj15.head(20)
# Out:
#    PCT                                              CRIME  2000  2001  2002  \
# 0    1  MURDER & NON NEGL. MANSLAUGHTER               ...     3     1     2
# 1    1             RAPE                                      12     5    10
# 2    1             ROBBERY                                  252   188   210
# 3    1             FELONY ASSAULT                           139   164   147
# 4    1             BURGLARY                                 475   437   297
# 5    1             GRAND LARCENY                           2358  2117  1896
# 6    1  GRAND LARCENY OF MOTOR VEHICLE                ...   199   157   153
# 7    1                  TOTAL SEVEN MAJOR FELONY OFFENSES  3438  3069  2715
# 8    5  MURDER & NON NEGL. MANSLAUGHTER               ...     4     3     0
# 9    5             RAPE                                       9     3    12
# 10   5             ROBBERY                                  351   261   196
# ...

# %%
crimemin15 = crimemin15[crimemin15['CRIME']=='TOTAL VIOLATION OFFENSES']
crimemin15.head()
# Out:
#    PCT                     CRIME  2000  2001  2002  2003  2004  2005  2006  \
# 2    1  TOTAL VIOLATION OFFENSES  1062   908   865   819   786   614   592
# 5    5  TOTAL VIOLATION OFFENSES   571   563   598   507   396   468   394
# 8    6  TOTAL VIOLATION OFFENSES   846   814   712   596   511   546   536
# 11   7  TOTAL VIOLATION OFFENSES   594   547   534   500   440   517   490
# 14   9  TOTAL VIOLATION OFFENSES  1032   997   971   864   809   826   760
#
#     2007  2008  2009  2010  2011  2012  2013  2014
# 2    692   569   447   438   647   749   498   608
# 5    427   474   455   431   426   468   362   427
# 8    455   443   435   502   550   474   433   458
# 11   480   571   465   454   416   487   438   506
# 14   640   707   695   651   662   678   605   584

# %%
crimemaj15 = crimemaj15[crimemaj15['CRIME']=='TOTAL SEVEN MAJOR FELONY OFFENSES']
crimemaj15.head()
# Out:
#    PCT                              CRIME  2000  2001  2002  2003  2004  2005  \
# 7    1  TOTAL SEVEN MAJOR FELONY OFFENSES  3438  3069  2715  2649  2383  2305
# 15   5  TOTAL SEVEN MAJOR FELONY OFFENSES  1780  1458  1309  1231  1170  1131
# 23   6  TOTAL SEVEN MAJOR FELONY OFFENSES  2387  2141  2059  2068  2174  2055
# 31   7  TOTAL SEVEN MAJOR FELONY OFFENSES   990   892   908   864   857   804
# 39   9  TOTAL SEVEN MAJOR FELONY OFFENSES  2115  1672  1809  1801  1747  1664
#
#     2006  2007  2008  2009  2010  2011  2012  2013  2014
# 7   2013  1914  1708  1578  1445  1402  1416  1416  1208
# 15  1040  1031  1029   975   969   962  1001   980   870
# 23  1979  1837  1738  1633  1530  1504  1574  1703  1575
# 31   864   856   807   702   702   704   762   711   732
# 39  1579  1519  1495  1523  1387  1350  1419  1424  1331

# %%
crimemin14 = pd.DataFrame(data=[crimemin15['PCT'], crimemin15[2013]])
crimemin14.head()
# Out:
#       2    5    8    11   14   17   20   23   26    29   32   35   38   41   \
# PCT     1    5    6    7    9   10   13   14   17    18   19   20   22   23
# 2013  498  362  433  438  605  437  732  695  320  1004  531  517   46  855
#
#       44   47   50   53   56   59   62   65    68   71   74    77    80   83   \
# PCT    24   25   26   28   30   32   33   34    40   41   42    43    44   45
# 2013  622  749  371  569  617  960  530  522  1317  929  923  1627  1350  855
#
#        86    89   92   95   98    101  104  107  110  113  116   119  122  \
# PCT     46    47   48   49   50    52   60   61   62   63   66    67   68
# 2013  1283  1065  853  814  534  1024  694  644  840  535  587  1294  768
#
#       125  128   131  134   137   140  143  146  149   152  155  158  161  \
# PCT    69   70    71   72    73    75   76   77   78    79   81   83   84
# 2013  796  884  1032  619  1506  1890  300  908  384  1111  963  827  603
#
# ...

# %%
crimemaj14 = pd.DataFrame(data=[crimemaj15['PCT'], crimemaj15[2013]])
crimemaj14.head()
# Out:
#        7    15    23   31    39    47    55    63    71    79    87   95   \
# PCT      1    5     6    7     9    10    13    14    17    18    19   20
# 2013  1416  980  1703  711  1424  1123  2152  2863  1024  2271  2064  969
#
#       103   111   119   127  135  143  151   159  167   175   183   191   199  \
# PCT    22    23    24    25   26   28   30    32   33    34    40    41    42
# 2013  104  1062  1022  1111  689  920  832  1000  927  1160  1902  1760  1335
#
#        207   215   223   231   239   247   255  263   271   279   287   295  \
# PCT     43    44    45    46    47    48    49   50    52    60    61    62
# 2013  2480  2191  1110  1681  2159  1768  1148  959  2206  1421  1666  1405
#
#        303   311   319  327   335   343   351   359   367   375  383   391  \
# PCT     63    66    67   68    69    70    71    72    73    75   76    77
# 2013  1296  1191  2383  947  1186  1832  1637  1206  2094  3902  637  1792
#
# ...

# %%
crimemin15 = pd.DataFrame(data=[crimemin15['PCT'], crimemin15[2014]])
crimemin15.head()
# Out:
#       2    5    8    11   14   17   20   23   26    29   32   35   38   41   \
# PCT     1    5    6    7    9   10   13   14   17    18   19   20   22   23
# 2014  608  427  458  506  584  420  692  855  360  1104  488  561   49  858
#
#       44   47   50   53   56   59   62   65    68   71    74    77    80   \
# PCT    24   25   26   28   30   32   33   34    40   41    42    43    44
# 2014  719  686  414  657  647  971  471  748  1392  941  1103  1612  1278
#
#        83    86    89   92   95   98    101  104  107  110  113  116   119  \
# PCT     45    46    47   48   49   50    52   60   61   62   63   66    67
# 2014  1016  1227  1159  919  786  525  1164  859  675  946  594  533  1673
#
#       122  125  128   131  134   137   140  143   146  149   152  155  158  \
# PCT    68   69   70    71   72    73    75   76    77   78    79   81   83
# 2014  631  878  964  1013  616  1487  2207  364  1104  442  1075  939  824
#
# ...

# %%
crimemaj15 = pd.DataFrame(data=[crimemaj15['PCT'], crimemaj15[2014]])
crimemaj15.head()
# Out:
#        7    15    23   31    39    47    55    63   71    79    87   95   103  \
# PCT      1    5     6    7     9    10    13    14   17    18    19   20   22
# 2014  1208  870  1575  732  1331  1022  2061  2744  909  2394  1913  899   83
#
#        111   119   127  135  143  151  159  167   175   183   191   199   207  \
# PCT     23    24    25   26   28   30   32   33    34    40    41    42    43
# 2014  1001  1020  1046  617  823  749  996  811  1151  1646  1291  1334  2452
#
#        215   223   231   239   247   255  263   271   279   287   295   303  \
# PCT     44    45    46    47    48    49   50    52    60    61    62    63
# 2014  2306  1149  1645  2035  1772  1073  973  2194  1465  1698  1286  1211
#
#        311   319  327   335   343   351   359   367   375  383   391  399  \
# PCT     66    67   68    69    70    71    72    73    75   76    77   78
# 2014  1154  2322  945  1153  1725  1500  1185  1879  3751  632  1664  956
#
# ...

# %%
crimemin14 = crimemin14.transpose()
crimemin15 = crimemin15.transpose()
crimemin15.head()
# Out:
#    PCT 2014
# 2    1  608
# 5    5  427
# 8    6  458
# 11   7  506
# 14   9  584

# %%
crimemaj14 = crimemaj14.transpose()
crimemaj14.head()
# Out:
#    PCT  2013
# 7    1  1416
# 15   5   980
# 23   6  1703
# 31   7   711
# 39   9  1424

# %%
crimemaj15 = crimemaj15.transpose()
crimemaj15.head()
# Out:
#    PCT  2014
# 7    1  1208
# 15   5   870
# 23   6  1575
# 31   7   732
# 39   9  1331

# %%
crimemin15 = crimemin15.rename(columns=({ 'PCT' : 'precinct', 2014: 'violation_offenses'}))
crimemin14 = crimemin14.rename(columns=({ 'PCT' : 'precinct', 2013: 'violation_offenses'}))

# %%
crimemaj15 = crimemaj15.rename(columns=({ 'PCT' : 'precinct', 2014: 'major_crimes'}))
crimemaj14 = crimemaj14.rename(columns=({ 'PCT' : 'precinct', 2013: 'major_crimes'}))

# %%
base15 = pd.merge(base15, crimemin15, how='left', on=['precinct'])
base15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 0 to 490
# Data columns (total 64 columns):
# DBN                                                               491 non-null object
# Enrollment                                                        491 non-null object
# Supportive Environment - Percent Positive                         491 non-null object
# Average Grade 8 English Proficiency                               491 non-null object
# Average Grade 8 Math Proficiency                                  491 non-null object
# Percent English Language Learners                                 491 non-null object
# Percent Students with Disabilities                                491 non-null object
# Percent Self-Contained                                            491 non-null object
# Percent Asian                                                     491 non-null object
# Percent Black                                                     491 non-null object
# ...

# %%
base14 = pd.merge(base14, crimemin14, how='left', on=['precinct'])
base14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 484 entries, 0 to 483
# Data columns (total 62 columns):
# DBN                                                               484 non-null object
# Enrollment                                                        478 non-null object
# Average Grade 8 English Proficiency                               478 non-null object
# Average Grade 8 Math Proficiency                                  478 non-null object
# Percent English Language Learners                                 478 non-null object
# Percent Students with Disabilities                                478 non-null object
# Percent Self-Contained                                            478 non-null object
# Percent Asian                                                     478 non-null object
# Percent Black                                                     478 non-null object
# Percent Hispanic                                                  478 non-null object
# ...

# %%
base15 = pd.merge(base15, crimemaj15, how='left', on=['precinct'])
base15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 0 to 490
# Data columns (total 65 columns):
# DBN                                                               491 non-null object
# Enrollment                                                        491 non-null object
# Supportive Environment - Percent Positive                         491 non-null object
# Average Grade 8 English Proficiency                               491 non-null object
# Average Grade 8 Math Proficiency                                  491 non-null object
# Percent English Language Learners                                 491 non-null object
# Percent Students with Disabilities                                491 non-null object
# Percent Self-Contained                                            491 non-null object
# Percent Asian                                                     491 non-null object
# Percent Black                                                     491 non-null object
# ...

# %%
base14 = pd.merge(base14, crimemaj14, how='left', on=['precinct'])
base14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 484 entries, 0 to 483
# Data columns (total 63 columns):
# DBN                                                               484 non-null object
# Enrollment                                                        478 non-null object
# Average Grade 8 English Proficiency                               478 non-null object
# Average Grade 8 Math Proficiency                                  478 non-null object
# Percent English Language Learners                                 478 non-null object
# Percent Students with Disabilities                                478 non-null object
# Percent Self-Contained                                            478 non-null object
# Percent Asian                                                     478 non-null object
# Percent Black                                                     478 non-null object
# Percent Hispanic                                                  478 non-null object
# ...

# %%
base14 = base14.rename(columns=({ '% of 4-year Cohort Taking SAT Math' : 'Percentage of 4-year Cohort Taking SAT Math', 'Years of Principal Experience at This School': 'Years of principal experience at this school',
                                '% of 4-year Cohort Taking ACT Math' : 'Percentage of 4-year Cohort Taking ACT Math', 'Four Year Graduation Rate': 'Metric Value - Graduation Rate, 4 year',
                                'Teacher Attendance': 'Teacher Attendance Rate', 'Attendance Rate': 'Student Attendance Rate'}))

# %%
# i have duplicates!!
base15.drop(base15.columns[[28]], axis=1, inplace=True)
base15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 0 to 490
# Data columns (total 63 columns):
# DBN                                                               491 non-null object
# Enrollment                                                        491 non-null object
# Supportive Environment - Percent Positive                         491 non-null object
# Average Grade 8 English Proficiency                               491 non-null object
# Average Grade 8 Math Proficiency                                  491 non-null object
# Percent English Language Learners                                 491 non-null object
# Percent Students with Disabilities                                491 non-null object
# Percent Self-Contained                                            491 non-null object
# Percent Asian                                                     491 non-null object
# Percent Black                                                     491 non-null object
# ...

# %%
# i have duplicates!!
base15.drop(base15.columns[[28]], axis=1, inplace=True)
base15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 0 to 490
# Data columns (total 61 columns):
# DBN                                                               491 non-null object
# Enrollment                                                        491 non-null object
# Supportive Environment - Percent Positive                         491 non-null object
# Average Grade 8 English Proficiency                               491 non-null object
# Average Grade 8 Math Proficiency                                  491 non-null object
# Percent English Language Learners                                 491 non-null object
# Percent Students with Disabilities                                491 non-null object
# Percent Self-Contained                                            491 non-null object
# Percent Asian                                                     491 non-null object
# Percent Black                                                     491 non-null object
# ...

# %%
per = sqr154['Percentage of 4-year Cohort Taking SAT Math'].iloc[:,0]

# %%
perr = sqr154['Average Score SAT Critical Reading'].iloc[:,0]

# %%
base15['% of 4-year Cohort Taking SAT Math'] = per

# %%
base15['Average Score SAT Critical Reading'] = perr

# %%
base15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 0 to 490
# Data columns (total 63 columns):
# DBN                                                               491 non-null object
# Enrollment                                                        491 non-null object
# Supportive Environment - Percent Positive                         491 non-null object
# Average Grade 8 English Proficiency                               491 non-null object
# Average Grade 8 Math Proficiency                                  491 non-null object
# Percent English Language Learners                                 491 non-null object
# Percent Students with Disabilities                                491 non-null object
# Percent Self-Contained                                            491 non-null object
# Percent Asian                                                     491 non-null object
# Percent Black                                                     491 non-null object
# ...

# %%
pd.set_option('display.max_columns', None)
base15.head()
# Out:
#       DBN Enrollment Supportive Environment - Percent Positive  \
# 0  01M292        255                                      0.77
# 1  01M448        304                                      0.87
# 2  01M450        666                                      0.92
# 3  01M509        363                                      0.81
# 4  01M539       1735                                      0.85
#
#   Average Grade 8 English Proficiency Average Grade 8 Math Proficiency  \
# 0                                2.18                             2.06
# 1                                2.27                             2.37
# 2                                2.66                             2.63
# 3                                2.28                             2.09
# 4                                 3.5                             3.53
#
#   Percent English Language Learners Percent Students with Disabilities  \
# 0                             0.127                              0.298
# ...

# %%
base15= base15.rename(columns=({ '% of 4-year Cohort Taking SAT Math' : 'Percentage of 4-year Cohort Taking SAT Math', }))

# %%
# this way I can make DBN the index and get rid of the 2015/2014 class year column
base15['DBN'] = '15' + base15['DBN']
base14['DBN'] = '14' + base14['DBN']

# %%
base15 = base15.set_index(['DBN'])
base14 = base14.set_index(['DBN'])

# %%
base = base15.append(base14, ignore_index=False)

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 975 entries, 1501M292 to 1484X703
# Data columns (total 62 columns):
# % Female                                                          956 non-null object
# % Male                                                            956 non-null object
# % Poverty                                                         956 non-null object
# 2015_avg_home_value_sqft                                          560 non-null float64
# Administrative District Code                                      863 non-null object
# Average Grade 8 English Proficiency                               969 non-null object
# Average Grade 8 Math Proficiency                                  969 non-null object
# Average Score Regents Algebra                                     897 non-null object
# Average Score Regents Algebra 2/Trig                              610 non-null object
# Average Score Regents Chemistry                                   533 non-null object
# ...

# %%
base = base.drop('class_grad_year', axis=1)

# %%
base = base.convert_objects(convert_numeric=True)
# Out:
# /Users/hopper/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':

# %%
pd.set_option('display.max_columns', None)
base.corr()
# Out:
#                                                     % Female    % Male  \
# % Female                                            1.000000 -1.000000
# % Male                                             -1.000000  1.000000
# % Poverty                                          -0.063817  0.063824
# 2015_avg_home_value_sqft                            0.209711 -0.209689
# Administrative District Code                       -0.093272  0.093257
# Average Grade 8 English Proficiency                 0.212558 -0.212553
# Average Grade 8 Math Proficiency                    0.136592 -0.136579
# Average Score Regents Algebra                       0.158973 -0.158960
# Average Score Regents Algebra 2/Trig                0.060772 -0.060720
# Average Score Regents Chemistry                     0.099588 -0.099531
# Average Score Regents Earth Science                 0.138498 -0.138496
# Average Score Regents English                       0.272955 -0.272953
# ...

# %%
base.shape
# Out:
# (975, 61)

# %%
base.to_csv('nyc_high_schools_complete_03062016.csv', index=True)
